# %% [markdown]
# # Statistics Advance-5 Assignment

# %% [markdown]
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.

# %%
from scipy import stats

sample_mean = 50
sample_std = 5
sample_size = 100

confidence_level = 0.95

standard_error = sample_std / (sample_size ** 0.5)

z_score = stats.norm.ppf((1 + confidence_level) / 2) 
margin_of_error = z_score * standard_error

confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (49.02001800772997, 50.97998199227003)

# %% [markdown]
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.

# %%
from scipy import stats

# Observed frequencies of colors in the bag of M&Ms
observed_freq = [22, 18, 19, 10, 11, 20] 

# Expected frequencies based on the given distribution
expected_freq = [0.2*100, 0.2*100, 0.2*100, 0.1*100, 0.1*100, 0.2*100]  

# Perform the chi-square test
chi2_stat, p_value = stats.chisquare(observed_freq, f_exp=expected_freq)

# Print the results
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)

# Check the significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The distribution of colors does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The distribution of colors matches the expected distribution.")
# Out:
# Chi-square statistic: 0.55
# P-value: 0.9901779302598364
# Fail to reject the null hypothesis: The distribution of colors matches the expected distribution.

# %% [markdown]
# Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:

# %% [markdown]
# It seems like you haven't provided the data for the contingency table. Could you please provide the data so that I can assist you in calculating the chi-square statistic and p-value using Python?

# %% [markdown]
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.

# %%
import scipy.stats as stats

# Sample data
total_population = 500
smokers = 60

# Calculate the sample proportion
sample_proportion = smokers / total_population

# Calculate the standard error
standard_error = (sample_proportion * (1 - sample_proportion) / total_population) ** 0.5

# Calculate the Z-score for a 95% confidence interval
confidence_level = 0.95
z_score = stats.norm.ppf((1 + confidence_level) / 2)

# Calculate the margin of error
margin_of_error = z_score * standard_error

# Calculate the confidence interval
confidence_interval = (sample_proportion - margin_of_error, sample_proportion + margin_of_error)

print("95% Confidence Interval for the true proportion of individuals who smoke:", confidence_interval)
# Out:
# 95% Confidence Interval for the true proportion of individuals who smoke: (0.09151638887130707, 0.1484836111286929)

# %% [markdown]
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

# Sample data
sample_mean = 75
sample_std = 12
sample_size = 100

# Confidence level
confidence_level = 0.90

# Calculate the standard error
standard_error = sample_std / (sample_size ** 0.5)

# Calculate the margin of error using the z-score
z_score = stats.norm.ppf((1 + confidence_level) / 2)  # Two-tailed test
margin_of_error = z_score * standard_error

# Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("90% Confidence Interval:", confidence_interval)
# Out:
# 90% Confidence Interval: (73.02617564765823, 76.97382435234177)

# %% [markdown]
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define the degrees of freedom
df = 10

# Generate x values for the chi-square distribution
x = np.linspace(0, 30, 1000)

# Calculate the probability density function (PDF) for the chi-square distribution
pdf = stats.chi2.pdf(x, df)

# Plot the chi-square distribution
plt.plot(x, pdf, label='Chi-square Distribution (df=10)')

# Shade the area corresponding to a chi-square statistic of 15
plt.fill_between(x, pdf, where=(x >= 15), color='blue', alpha=0.3, label='Chi-square Statistic of 15')

# Label the axes
plt.xlabel('Chi-square Statistic')
plt.ylabel('Probability Density')

# Add a legend
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\baras\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.

# %%
import scipy.stats as stats

# Sample data
total_sample_size = 1000
coke_preference = 520

# Calculate the sample proportion
sample_proportion = coke_preference / total_sample_size

# Calculate the standard error
standard_error = (sample_proportion * (1 - sample_proportion) / total_sample_size) ** 0.5

# Calculate the Z-score for a 99% confidence interval
confidence_level = 0.99
z_score = stats.norm.ppf((1 + confidence_level) / 2)

# Calculate the margin of error
margin_of_error = z_score * standard_error

# Calculate the confidence interval
confidence_interval = (sample_proportion - margin_of_error, sample_proportion + margin_of_error)

print("99% Confidence Interval for the true proportion of people who prefer Coke:", confidence_interval)
# Out:
# 99% Confidence Interval for the true proportion of people who prefer Coke: (0.4793051576779699, 0.5606948423220302)

# %% [markdown]
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.

# %%
import scipy.stats as stats

# Observed frequencies
observed_freq = [45, 55]  # Tails, Heads

# Expected frequencies for a fair coin
expected_freq = [50, 50]  # Tails, Heads

# Perform the chi-square goodness of fit test
chi2_stat, p_value = stats.chisquare(observed_freq, f_exp=expected_freq)

# Print the results
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)

# Check the significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed frequencies do not match the expected frequencies of a fair coin.")
else:
    print("Fail to reject the null hypothesis: The observed frequencies match the expected frequencies of a fair coin.")
# Out:
# Chi-square statistic: 1.0
# P-value: 0.31731050786291115
# Fail to reject the null hypothesis: The observed frequencies match the expected frequencies of a fair coin.

# %% [markdown]
# Q9. A study was conducted to determine if there is an association between smoking status (smoker or
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
# Conduct a chi-square test for independence to determine if there is a significant association between
# smoking status and lung cancer diagnosis.

# %%
import numpy as np
import scipy.stats as stats

# Contingency table
observed = np.array([[20, 30], [10, 40]])  # Rows: smoker (yes, no), Columns: lung cancer diagnosis (yes, no)

# Perform the chi-square test for independence
chi2_stat, p_value, dof, expected = stats.chi2_contingency(observed)

# Print the results
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)

# Check the significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between smoking status and lung cancer diagnosis.")
# Out:
# Chi-square statistic: 3.8571428571428577
# P-value: 0.04953461343562649
# Reject the null hypothesis: There is a significant association between smoking status and lung cancer diagnosis.

# %% [markdown]
# Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant
# association between chocolate preference and country of origin.

# %%
import numpy as np
import scipy.stats as stats

# Contingency table
observed = np.array([[150, 200, 150], [180, 150, 170]])  # Rows: U.S., U.K.; Columns: Milk, Dark, White

# Perform the chi-square test for independence
chi2_stat, p_value, dof, expected = stats.chi2_contingency(observed)

# Print the results
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_value)

# Check the significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant association between chocolate preference and country of origin.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between chocolate preference and country of origin.")
# Out:
# Chi-square statistic: 11.12012987012987
# P-value: 0.003848526485179367
# Reject the null hypothesis: There is a significant association between chocolate preference and country of origin.

# %% [markdown]
# Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
# significance level of 0.05.

# %%
import scipy.stats as stats

# Sample data
sample_mean = 72
sample_std = 10
sample_size = 30
population_mean = 70

# Perform the one-sample t-test
t_statistic, p_value = stats.ttest_1samp(a=sample_mean, popmean=population_mean)

# Print the results
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Check the significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The population mean is significantly different from 70.")
else:
    print("Fail to reject the null hypothesis: The population mean is not significantly different from 70.")
# Out:
# T-statistic: nan
# P-value: nan
# Fail to reject the null hypothesis: The population mean is not significantly different from 70.
# C:\Users\baras\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1103: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# C:\Users\baras\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1103: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
